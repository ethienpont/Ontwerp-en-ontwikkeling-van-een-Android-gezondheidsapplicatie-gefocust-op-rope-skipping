# %%
# %matplotlib notebook
import pandas as pd
import numpy as np
import math
import statistics
from datetime import datetime
from sklearn.model_selection import train_test_split
from sklearn import preprocessing
from sklearn.ensemble import RandomForestClassifier, ExtraTreesClassifier, AdaBoostClassifier
from sklearn.model_selection import GridSearchCV
from sklearn.linear_model import SGDClassifier
from sklearn.naive_bayes import GaussianNB, MultinomialNB
from sklearn.neighbors import KNeighborsClassifier
from sklearn.svm import SVC, LinearSVC
from sklearn import svm
from sklearn.neural_network import MLPClassifier
from sklearn.metrics import confusion_matrix, classification_report
from sklearn.preprocessing import StandardScaler, LabelEncoder, normalize
import matplotlib.pyplot as plt
import seaborn as sn
import matplotlib
from mlxtend.plotting import plot_confusion_matrix
import warnings
from scipy.signal import savgol_filter, find_peaks, correlate
from sklearn.decomposition import PCA
import scipy.fftpack as FFT
from sklearn.utils import shuffle
import joblib
import scipy.stats as stats
warnings.filterwarnings('ignore')
matplotlib.rcParams['figure.figsize'] = [12,5]

# %%
def sampling_freq(df):
    start = df['time'].iloc[0]
    sum_samples = 0
    index = 0
    while  (start + pd.to_timedelta(1, unit='s')) < df['time'].iloc[-1]:
        end =  start + pd.to_timedelta(1, unit='s')
        sum_samples += df[(df['time'] >= start) & (df['time'] < end)].shape[0]
        start += pd.to_timedelta(1, unit='s')
        index += 1
    return sum_samples/index

def convert_to_float(x):
    try:
        return np.float(x)
    except:
        return np.nan

def convert_to_datetime(x):
    dt = datetime.fromtimestamp(x // 1000000000)
    s = dt.strftime('%Y-%m-%d %H:%M:%S')
    s += '.' + str(int(x % 1000000000)).zfill(9)
    return s

def heatmap(cm, labels):
    df_cm = pd.DataFrame(cm, index=labels, columns=labels)
    plt.figure(figsize = (10,7))
    sn.heatmap(df_cm, annot=True)

    plt.show()
    
def preprocess(data, activity, drop_interval_begin = 3, drop_interval_end = 3):
    #convert nanoseconds to date 
    data['time'] = data['time'].apply(convert_to_datetime) 
    data['time'] = pd.to_datetime(data['time'])

#convert to same data type
    for i in range(1, 4): 
        data[column_names_org[i]] = data[column_names_org[i]].apply(convert_to_float)
    
#drop rows with NaN values 
    data.dropna(axis=0, how='any', inplace=True) #TODO: invullen met mean, mod of median / interpolatie

#drop duplicates 
    data.drop_duplicates(subset=None, keep='first', inplace = True)
    
    #drop first and last 3 sec
    indexFirst = data[ (data['time'].iloc[0]+ pd.to_timedelta(drop_interval_begin, unit='s')) > data['time'] ].index
    data.drop(indexFirst , inplace=True)
    indexLast = data[ (data['time'].iloc[-1]- pd.to_timedelta(drop_interval_end, unit='s')) < data['time'] ].index
    data.drop(indexLast , inplace=True)
    
    #add activity label
    data['activity'] = activity
    
    return data

#TODO: verschillende activiteiten in 1 frame
def get_frames(df, frame_size, hop_size):

    N_FEATURES = 3

    frames = []
    labels = []
    for i in range(0, len(df) - frame_size, hop_size):
        x = df['x'].values[i: i + frame_size]
        y = df['y'].values[i: i + frame_size]
        z = df['z'].values[i: i + frame_size]
       
        # Retrieve the most often used label in this segment
        label = stats.mode(df['activity'][i: i + frame_size])[0][0]
        frames.append([x, y, z])
        labels.append(label)

    # Bring the segments into a better shape
    frames = np.asarray(frames).reshape(-1, frame_size, N_FEATURES)
    labels = np.asarray(labels)

    return frames, labels

# %%
column_names_org = ['time', 'x', 'y', 'z']
moves = ["jump_fast", "jump_slow", "side_swing", "cross_over", "forward_180"]
moves_df = {}

# %% [markdown]
# # PREPROCESSING

# %% [markdown]
# ## jump fast

# %%
jump_fast_files = ["jump_fast.csv", "jump_fast (meting2).csv"]
jump_fast_df = []

# %%
for f in jump_fast_files:
    jump_fast = pd.read_csv(r"C:\Users\Elise\Documents\unif\master\semester2\masterproef\gitProject\thesis\data\\" + f, sep=';', header=0, skipinitialspace=True)
    jump_fast = preprocess(jump_fast, "jump_fast")
    jump_fast_df.append(jump_fast)

# %%
#preserve raw data
jump_fast_raw =  pd.concat(jump_fast_df, ignore_index=True)
moves_df["jump_fast"] = jump_fast_raw
jump_fast_raw.head()
# Out:
#                            time          x          y          z   activity
# 0 1970-01-01 01:23:31.161128960 -13.727624  -5.393422  10.435100  jump_fast
# 1 1970-01-01 01:23:31.179347968 -14.868999  -8.697910  10.521241  jump_fast
# 2 1970-01-01 01:23:31.198877696 -17.388641  -6.417551   2.141576  jump_fast
# 3 1970-01-01 01:23:31.218669568 -28.742586 -34.614571   9.489935  jump_fast
# 4 1970-01-01 01:23:31.237543936 -12.117254 -13.351951   8.276773  jump_fast

# %%
freq = {}

# %%
freq["jump_fast"] = 0
for df in jump_fast_df:
    f = sampling_freq(df)
    freq["jump_fast"] += f
freq["jump_fast"] /= len(jump_fast_df)
freq
# Out:
# {'jump_fast': 51.828947368421055}

# %% [markdown]
# ## jump slow

# %%
jump_slow_files = ["jump_slow.csv", "jump_slow1 (meting2).csv"]
jump_slow_df = []

# %%
for f in jump_slow_files:
    d = pd.read_csv(r"C:\Users\Elise\Documents\unif\master\semester2\masterproef\gitProject\thesis\data\\" + f, sep=';', header=0, skipinitialspace=True)
    d = preprocess(d, "jump_slow")
    jump_slow_df.append(d)

# %%
#preserve raw data
jump_slow_raw =  pd.concat(jump_slow_df, ignore_index=True)
moves_df["jump_slow"] = jump_slow_raw
jump_slow_raw.head()
# Out:
#                            time         x         y         z   activity
# 0 1970-01-01 01:22:43.384205312  5.812166 -7.269395 -5.000999  jump_slow
# 1 1970-01-01 01:22:43.403997184 -1.052842 -5.434100 -2.892923  jump_slow
# 2 1970-01-01 01:22:43.422347264 -4.833502 -8.195417 -3.342773  jump_slow
# 3 1970-01-01 01:22:43.442663424 -8.176275 -9.966106 -6.037092  jump_slow
# 4 1970-01-01 01:22:43.461931008 -7.305287 -7.922636 -9.257831  jump_slow

# %%
freq["jump_slow"] = 0
for df in jump_slow_df:
    f = sampling_freq(df)
    freq["jump_slow"] += f
freq["jump_slow"] /= len(jump_slow_df)
freq
# Out:
# {'jump_fast': 51.828947368421055, 'jump_slow': 51.85828877005348}

# %% [markdown]
# ## side swing

# %%
side_swing_files = ["side_swing.csv", "side_swing2 (meting2).csv", "side_swing3 (meting2).csv"]
side_swing_df = []

# %%
for f in side_swing_files:
    d = pd.read_csv(r"C:\Users\Elise\Documents\unif\master\semester2\masterproef\gitProject\thesis\data\\" + f, sep=';', header=0, skipinitialspace=True)
    d = preprocess(d, "side_swing")
    side_swing_df.append(d)

# %%
#preserve raw data
side_swing_raw =  pd.concat(side_swing_df, ignore_index=True)
moves_df["side_swing"] = side_swing_raw
side_swing_raw.head()
# Out:
#                            time         x          y         z    activity
# 0 1970-01-01 04:25:01.846446080 -4.242475  -8.889337  2.167897  side_swing
# 1 1970-01-01 04:25:01.859028992 -4.242475  -8.889337  2.167897  side_swing
# 2 1970-01-01 04:25:01.871611904 -5.032106  -9.166903  3.656233  side_swing
# 3 1970-01-01 04:25:01.887340544 -4.862216  -9.195618  5.790631  side_swing
# 4 1970-01-01 04:25:01.911457792 -4.972285 -10.100104  5.395815  side_swing

# %%
freq["side_swing"] = 0
for df in side_swing_df:
    f = sampling_freq(df)
    freq["side_swing"] += f
freq["side_swing"] /= len(side_swing_df)
freq
# Out:
# {'jump_fast': 51.828947368421055,
#  'jump_slow': 51.85828877005348,
#  'side_swing': 52.17316017316017}

# %% [markdown]
# ## cross over

# %%
cross_over_files = ["cross_over2.csv", "cross_over3.csv", "cross_over4.csv", "cross_over5.csv"]
cross_over_df = []

# %%
for f in cross_over_files:
    d = pd.read_csv(r"C:\Users\Elise\Documents\unif\master\semester2\masterproef\gitProject\thesis\data\\" + f, sep=';', header=0, skipinitialspace=True)
    d = preprocess(d, "cross_over")
    cross_over_df.append(d)

# %%
#preserve raw data
cross_over_raw =  pd.concat(cross_over_df, ignore_index=True)
moves_df["cross_over"] = cross_over_raw
cross_over_raw.head()
# Out:
#                            time          x          y          z    activity
# 0 1970-01-01 11:20:00.582410240  -2.160719  -6.233303 -14.897714  cross_over
# 1 1970-01-01 11:20:00.599187456  -3.905087 -10.815558 -13.521841  cross_over
# 2 1970-01-01 11:20:00.620158976  -6.647261 -13.981263 -12.650853  cross_over
# 3 1970-01-01 11:20:00.641130496 -10.040284 -15.531812 -11.734403  cross_over
# 4 1970-01-01 11:20:00.657907712  -7.441679 -21.116659 -14.184652  cross_over

# %%
freq["cross_over"] = 0
for df in cross_over_df:
    f = sampling_freq(df)
    freq["cross_over"] += f
freq["cross_over"] /= len(cross_over_df)
freq
# Out:
# {'jump_fast': 51.828947368421055,
#  'jump_slow': 51.85828877005348,
#  'side_swing': 52.17316017316017,
#  'cross_over': 52.37883116883117}

# %% [markdown]
# ## forward 180

# %%
forward_180_files = ["forward_180_2.csv"]
forward_180_df = []

# %%
for f in forward_180_files:
    d = pd.read_csv(r"C:\Users\Elise\Documents\unif\master\semester2\masterproef\gitProject\thesis\data\\" + f, sep=';', header=0, skipinitialspace=True)
    d = preprocess(d, "forward_180")
    forward_180_df.append(d)

# %%
#preserve raw data
forward_180_raw = forward_180
moves_df["forward_180"] = forward_180_raw
forward_180_raw.head()
# Out:
#                              time          x          y         z     activity
# 202 1970-01-01 11:32:59.263336448 -18.680767 -12.942778  5.675776  forward_180
# 203 1970-01-01 11:32:59.284307968 -16.331015 -10.521241  5.505885  forward_180
# 204 1970-01-01 11:32:59.305279488 -17.601603  -3.617948  5.479564  forward_180
# 205 1970-01-01 11:32:59.322056704 -18.474983  -5.826523  7.613962  forward_180
# 206 1970-01-01 11:32:59.343028224 -16.907684  -7.776674  8.197810  forward_180

# %%
freq["forward_180"] = 0
for df in forward_180_df:
    f = sampling_freq(df)
    freq["forward_180"] += f
freq["forward_180"] /= len(forward_180_df)
freq
# Out:
# {'jump_fast': 51.828947368421055,
#  'jump_slow': 51.85828877005348,
#  'side_swing': 52.17316017316017,
#  'cross_over': 52.37883116883117,
#  'forward_180': 51.81666666666667}

# %% [markdown]
# # CLASSIFICATION

# %% [markdown]
# ## shuffle - balance data

# %%
shape = np.min([jump_fast_raw.shape[0], jump_slow_raw.shape[0], side_swing_raw.shape[0], cross_over_raw.shape[0], forward_180_raw.shape[0]])
jump_fast_raw = shuffle(jump_fast_raw).head(shape).copy()
jump_slow_raw = shuffle(jump_slow_raw).head(shape).copy()
side_swing_raw = shuffle(side_swing_raw).head(shape).copy()
cross_over_raw = shuffle(cross_over_raw).head(shape).copy()
forward_180_raw = shuffle(forward_180_raw).head(shape).copy()
moves_df["jump_fast"] = jump_fast_raw
moves_df["jump_slow"] = jump_slow_raw
moves_df["side_swing"] = side_swing_raw
moves_df["cross_over"] = cross_over_raw
moves_df["forward_180"] = forward_180_raw
shape
# Out:
# 2939

# %% [markdown]
# ## merge activities

# %%
merged_raw = pd.concat([jump_fast_raw, jump_slow_raw, side_swing_raw, cross_over_raw, forward_180_raw], ignore_index=True) 
target = merged_raw['activity']
merged_raw
# Out:
#                                time          x          y          z  \
# 0     1970-01-01 04:38:30.127624192   9.121440  -4.378865  -5.955736
# 1     1970-01-01 04:38:04.480503808   1.244268 -13.306487 -11.298908
# 2     1970-01-01 04:38:30.795567104 -16.587046 -16.972292  12.679567
# 3     1970-01-01 01:23:47.172884480  -5.125426  -5.608776  -7.688139
# 4     1970-01-01 04:38:31.265329152 -18.539589 -13.524234   3.871587
# ...                             ...        ...        ...        ...
# 14690 1970-01-01 11:33:38.119368704  -2.189433  -2.478964   3.811766
# 14691 1970-01-01 11:33:34.738759680  -2.074577 -13.308880  -2.840281
# 14692 1970-01-01 11:34:05.181018112   0.988236  -6.628119  -6.692725
# 14693 1970-01-01 11:33:26.194962432 -10.315458  -4.895715  -2.715854
# 14694 1970-01-01 11:34:56.842260480 -21.925434 -18.587446 -14.447864
#
#           activity
# 0        jump_fast
# 1        jump_fast
# 2        jump_fast
# 3        jump_fast
# 4        jump_fast
# ...            ...
# 14690  forward_180
# 14691  forward_180
# 14692  forward_180
# 14693  forward_180
# 14694  forward_180
#
# [14695 rows x 5 columns]

# %% [markdown]
# ## labeling

# %%
#label activity
le = preprocessing.LabelEncoder()
le.fit(merged_raw['activity'])
merged_raw['activity'] = le.transform(merged_raw['activity'])
labels = le.inverse_transform([0,1,2,3,4])
labels
# Out:
# array(['cross_over', 'forward_180', 'jump_fast', 'jump_slow',
#        'side_swing'], dtype=object)

# %% [markdown]
# ## normalize

# %%
Normalizer = preprocessing.Normalizer().fit(merged_raw[['x', 'y', 'z']])
merged_raw[['x', 'y', 'z']] = Normalizer.transform(merged_raw[['x', 'y', 'z']])
merged_raw.head()
# Out:
#                            time         x         y         z  activity
# 0 1970-01-01 04:38:30.127624192  0.776902 -0.372962 -0.507269         2
# 1 1970-01-01 04:38:04.480503808  0.071098 -0.760338 -0.645624         2
# 2 1970-01-01 04:38:30.795567104 -0.616470 -0.630788  0.471245         2
# 3 1970-01-01 01:23:47.172884480 -0.474179 -0.518896 -0.711268         2
# 4 1970-01-01 04:38:31.265329152 -0.796630 -0.581124  0.166359         2

# %% [markdown]
# ## segmentation

# %%
sampling_freq=sum(freq.values())/len(freq)
sampling_freq
# Out:
# 52.01117882942651

# %%
frame_size = int(sampling_freq)*1
hop_size = int(frame_size/2)

# %%
X, y = get_frames(merged_raw.drop('time', axis=1), frame_size, hop_size)

# %% [markdown]
# ## neural network

# %%
X.shape, y.shape
# Out:
# ((564, 52, 3), (564,))

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.2, random_state = 0, stratify = y)

# %%
X_train.shape, X_test.shape
# Out:
# ((451, 52, 3), (113, 52, 3))

# %%
X_train = X_train.reshape(X_train.shape[0], X_train.shape[1], X_train.shape[2], 1)
X_test = X_test.reshape(X_test.shape[0], X_test.shape[1], X_test.shape[2], 1)

# %%
X_train[0].shape, X_test[0].shape
# Out:
# ((52, 3, 1), (52, 3, 1))

# %%
import tensorflow as tf
from tensorflow.keras import Sequential
from tensorflow.keras.layers import Flatten, Dense, Dropout, BatchNormalization
from tensorflow.keras.layers import Conv2D, MaxPool2D
from tensorflow.keras.optimizers import Adam

# %%
model = Sequential()
model.add(Conv2D(16, (3, 3), activation = 'relu', input_shape = X_train[0].shape))
model.add(BatchNormalization())
model.add(Dropout(0.1))

model.add(Conv2D(32, (1, 1), activation='relu'))
model.add(Dropout(0.2))

model.add(Flatten())

model.add(Dense(64, activation = 'relu'))
model.add(Dropout(0.5))

model.add(Dense(7, activation='softmax'))

# %%
model.compile(optimizer=Adam(learning_rate = 0.001), loss = 'sparse_categorical_crossentropy', metrics = ['accuracy'])

# %%
epo = 30
history = model.fit(X_train, y_train, epochs = epo, batch_size=64, validation_data= (X_test, y_test), verbose=1, shuffle=True)
# Out:
# Train on 451 samples, validate on 113 samples
# Epoch 1/30
# 451/451 [==============================] - 3s 8ms/sample - loss: 2.0610 - accuracy: 0.1929 - val_loss: 1.7642 - val_accuracy: 0.4602
# Epoch 2/30
# 451/451 [==============================] - 0s 419us/sample - loss: 1.3292 - accuracy: 0.4346 - val_loss: 1.6934 - val_accuracy: 0.4513
# Epoch 3/30
# 451/451 [==============================] - 0s 387us/sample - loss: 1.0727 - accuracy: 0.5787 - val_loss: 1.6005 - val_accuracy: 0.4248
# Epoch 4/30
# 451/451 [==============================] - 0s 548us/sample - loss: 0.8613 - accuracy: 0.6630 - val_loss: 1.5186 - val_accuracy: 0.4779
# Epoch 5/30
# 451/451 [==============================] - 0s 502us/sample - loss: 0.7250 - accuracy: 0.6984 - val_loss: 1.4227 - val_accuracy: 0.6106
# Epoch 6/30
# 451/451 [==============================] - 1s 2ms/sample - loss: 0.6792 - accuracy: 0.7317 - val_loss: 1.3866 - val_accuracy: 0.4956
# Epoch 7/30
# 451/451 [==============================] - 0s 388us/sample - loss: 0.6119 - accuracy: 0.7406 - val_loss: 1.3716 - val_accuracy: 0.4779
# Epoch 8/30
# 451/451 [==============================] - 0s 313us/sample - loss: 0.5068 - accuracy: 0.8226 - val_loss: 1.2955 - val_accuracy: 0.5310
# Epoch 9/30
# 451/451 [==============================] - 0s 479us/sample - loss: 0.4723 - accuracy: 0.8248 - val_loss: 1.1991 - val_accuracy: 0.6106
# Epoch 10/30
# 451/451 [==============================] - 0s 403us/sample - loss: 0.4348 - accuracy: 0.8404 - val_loss: 1.1088 - val_accuracy: 0.6814
# Epoch 11/30
# 451/451 [==============================] - 0s 472us/sample - loss: 0.3731 - accuracy: 0.8537 - val_loss: 1.0481 - val_accuracy: 0.6903
# Epoch 12/30
# 451/451 [==============================] - 1s 2ms/sample - loss: 0.3712 - accuracy: 0.8603 - val_loss: 1.0322 - val_accuracy: 0.6018
# Epoch 13/30
# 451/451 [==============================] - 0s 344us/sample - loss: 0.3670 - accuracy: 0.8670 - val_loss: 0.9608 - val_accuracy: 0.7080
# Epoch 14/30
# 451/451 [==============================] - 0s 308us/sample - loss: 0.2792 - accuracy: 0.9069 - val_loss: 0.8868 - val_accuracy: 0.7434
# Epoch 15/30
# 451/451 [==============================] - 0s 368us/sample - loss: 0.2657 - accuracy: 0.9202 - val_loss: 0.8526 - val_accuracy: 0.7522
# Epoch 16/30
# 451/451 [==============================] - 0s 929us/sample - loss: 0.2778 - accuracy: 0.8980 - val_loss: 0.8251 - val_accuracy: 0.7080
# Epoch 17/30
# 451/451 [==============================] - 1s 2ms/sample - loss: 0.2752 - accuracy: 0.8758 - val_loss: 0.7696 - val_accuracy: 0.7345
# Epoch 18/30
# 451/451 [==============================] - 1s 1ms/sample - loss: 0.2276 - accuracy: 0.9047 - val_loss: 0.7655 - val_accuracy: 0.7611
# Epoch 19/30
# 451/451 [==============================] - 0s 1ms/sample - loss: 0.2054 - accuracy: 0.9401 - val_loss: 0.7390 - val_accuracy: 0.7699
# Epoch 20/30
# 451/451 [==============================] - 1s 1ms/sample - loss: 0.2191 - accuracy: 0.9202 - val_loss: 0.6811 - val_accuracy: 0.7699
# Epoch 21/30
# 451/451 [==============================] - 1s 1ms/sample - loss: 0.2392 - accuracy: 0.9180 - val_loss: 0.6617 - val_accuracy: 0.7699
# Epoch 22/30
# 451/451 [==============================] - 1s 2ms/sample - loss: 0.2077 - accuracy: 0.9357 - val_loss: 0.6122 - val_accuracy: 0.7788
# Epoch 23/30
# 451/451 [==============================] - 0s 1ms/sample - loss: 0.2037 - accuracy: 0.9180 - val_loss: 0.5884 - val_accuracy: 0.7788
# Epoch 24/30
# 451/451 [==============================] - 0s 492us/sample - loss: 0.1814 - accuracy: 0.9401 - val_loss: 0.5846 - val_accuracy: 0.7788
# Epoch 25/30
# 451/451 [==============================] - 0s 406us/sample - loss: 0.1412 - accuracy: 0.9534 - val_loss: 0.5916 - val_accuracy: 0.7788
# Epoch 26/30
# 451/451 [==============================] - 0s 437us/sample - loss: 0.1914 - accuracy: 0.9202 - val_loss: 0.6281 - val_accuracy: 0.7611
# Epoch 27/30
# 451/451 [==============================] - 1s 1ms/sample - loss: 0.2038 - accuracy: 0.9357 - val_loss: 0.5888 - val_accuracy: 0.7788
# Epoch 28/30
# 451/451 [==============================] - 0s 905us/sample - loss: 0.1551 - accuracy: 0.9557 - val_loss: 0.5450 - val_accuracy: 0.7876
# Epoch 29/30
# 451/451 [==============================] - 0s 430us/sample - loss: 0.1686 - accuracy: 0.9268 - val_loss: 0.5394 - val_accuracy: 0.8053
# Epoch 30/30
# 451/451 [==============================] - 0s 967us/sample - loss: 0.1504 - accuracy: 0.9446 - val_loss: 0.5416 - val_accuracy: 0.7965

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              (None, 50, 1, 16)         160
# _________________________________________________________________
# batch_normalization (BatchNo (None, 50, 1, 16)         64
# _________________________________________________________________
# dropout (Dropout)            (None, 50, 1, 16)         0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 50, 1, 32)         544
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 50, 1, 32)         0
# _________________________________________________________________
# flatten (Flatten)            (None, 1600)              0
# _________________________________________________________________
# dense (Dense)                (None, 64)                102464
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 64)                0
# _________________________________________________________________
# dense_1 (Dense)              (None, 7)                 455
# =================================================================
# Total params: 103,687
# Trainable params: 103,655
# Non-trainable params: 32
# _________________________________________________________________

# %%
def plot_learningCurve(history, epochs):
  # Plot training & validation accuracy values
  epoch_range = range(1, epochs+1)
  plt.plot(epoch_range, history.history['accuracy'])
  plt.plot(epoch_range, history.history['val_accuracy'])
  plt.title('Model accuracy')
  plt.ylabel('Accuracy')
  plt.xlabel('Epoch')
  plt.legend(['Train', 'Val'], loc='upper left')
  plt.show()

  # Plot training & validation loss values
  plt.plot(epoch_range, history.history['loss'])
  plt.plot(epoch_range, history.history['val_loss'])
  plt.title('Model loss')
  plt.ylabel('Loss')
  plt.xlabel('Epoch')
  plt.legend(['Train', 'Val'], loc='upper left')
  plt.show()

# %%
plt.figure()
plot_learningCurve(history, epo)
# Out:
# <img src="data:image/png;base64,..." width="1200">

# %%
y_pred = model.predict_classes(X_test)

# %%
mat = confusion_matrix(y_test, y_pred)
results = model.evaluate(X_test, y_test, batch_size=128)
print('test loss, test acc:', results)
heatmap(mat, labels)
# Out:
# 113/113 [==============================] - 0s 141us/sample - loss: 0.5416 - accuracy: 0.7965
# test loss, test acc: [0.5416392683982849, 0.79646015]
# <img src="data:image/png;base64,..." width="1000">

# %% [markdown]
# ##
