# %% [markdown]
# In this notebook al the data of side swing is read and processed. This includes all variations in measuring of the movement. The shuffeling of the dataset was not done for constructing the CNN datasets.

# %%
# %matplotlib notebook
import pandas as pd
import numpy as np
import math
import statistics
from datetime import datetime
from sklearn.model_selection import train_test_split
from sklearn import preprocessing
from sklearn.ensemble import RandomForestClassifier, ExtraTreesClassifier, AdaBoostClassifier
from sklearn.model_selection import GridSearchCV
from sklearn.linear_model import SGDClassifier
from sklearn.naive_bayes import GaussianNB, MultinomialNB
from sklearn.neighbors import KNeighborsClassifier
from sklearn.svm import SVC, LinearSVC
from sklearn import svm
from sklearn.neural_network import MLPClassifier
from sklearn.metrics import confusion_matrix, classification_report
from sklearn.preprocessing import StandardScaler, LabelEncoder, normalize
import matplotlib.pyplot as plt
import seaborn as sn
import matplotlib
import warnings
from scipy.signal import savgol_filter, find_peaks, correlate
from sklearn.decomposition import PCA
import scipy.fftpack as FFT
from sklearn.utils import shuffle
import joblib
warnings.filterwarnings('ignore')
matplotlib.rcParams['figure.figsize'] = [12,5]

# %% [markdown]
# ## help functions

# %%
def sampling_freq(df):
    start = df['time'].iloc[0]
    sum_samples = 0
    index = 0
    while  (start + pd.to_timedelta(1, unit='s')) < df['time'].iloc[-1]:
        end =  start + pd.to_timedelta(1, unit='s')
        sum_samples += df[(df['time'] >= start) & (df['time'] < end)].shape[0]
        start += pd.to_timedelta(1, unit='s')
        index += 1
    return sum_samples/index

def convert_to_float(x):
    try:
        return np.float(x)
    except:
        return np.nan

def convert_to_datetime(x):
    dt = datetime.fromtimestamp(x // 1000000000)
    s = dt.strftime('%Y-%m-%d %H:%M:%S')
    s += '.' + str(int(x % 1000000000)).zfill(9)
    return s

def heatmap(cm, labels):
    df_cm = pd.DataFrame(cm, index=labels, columns=labels)
    plt.figure(figsize = (10,7))
    sn.heatmap(df_cm, annot=True)

    plt.show()
    
def preprocess(data, activity, type_, p, drop_interval_begin = 3, drop_interval_end = 3):
    #convert nanoseconds to date 
    data['time'] = data['time'].apply(convert_to_datetime) 
    data['time'] = pd.to_datetime(data['time'])

#convert to same data type
    for i in range(1, 4): 
        data[column_names_org[i]] = data[column_names_org[i]].apply(convert_to_float)
    
#drop rows with NaN values 
    data.dropna(axis=0, how='any', inplace=True) #TODO: invullen met mean, mod of median / interpolatie

#drop duplicates 
    data.drop_duplicates(subset=None, keep='first', inplace = True)
    
    #drop first and last 3 sec
    indexFirst = data[ (data['time'].iloc[0]+ pd.to_timedelta(drop_interval_begin, unit='s')) > data['time'] ].index
    data.drop(indexFirst , inplace=True)
    indexLast = data[ (data['time'].iloc[-1]- pd.to_timedelta(drop_interval_end, unit='s')) < data['time'] ].index
    data.drop(indexLast , inplace=True)
    
    #add activity label
    data['activity'] = activity
    data['type'] = type_
    data['proefpersoon'] = p
    
    return data

#feature extraction
def get_mean_window(df):
    return df.mean()

def get_min_window(df):
    return df.min()

def get_max_window(df):
    return df.max()

def get_std_window(df):
    return df.std()

def get_med_window(df):
    return df.median()

#measure of activity level (m/s²)
def get_signal_magnitude_area(df):
        sum = 0
        for i in range(0, len(df)):
            sum += (abs(df['x'].iloc[i]) + abs(df['y'].iloc[i]) + abs(df['z'].iloc[i]))
        return sum /len(df)

#degree of movement intensity (m/s²)
def get_signal_magnitude_vector(df):
    sum = 0
    for i in range(0, len(df)):
        sum += math.sqrt(df['x'].iloc[i] * df['x'].iloc[i] + df['y'].iloc[i] * df['y'].iloc[i] + df['z'].iloc[i] * df['z'].iloc[i])
    return sum

#average angle (radian) between accelerometer vector and x as (parallel with arm)
def get_tilt_angle(df):
    df_cos = pd.DataFrame(columns=["tilt_ang"])
    df_dot = df['x']
    for i in range(0, len(df)):
        s = pd.Series({"tilt_ang" : (df_dot.iloc[i])/(math.sqrt(df['x'].iloc[i]*df['x'].iloc[i] + df['y'].iloc[i]*df['y'].iloc[i] + df['z'].iloc[i]*df['z'].iloc[i]))})
        df_cos=df_cos.append(s, ignore_index=True)
    df_angle = np.arccos(df_cos)
    return df_angle.mean()['tilt_ang']

def get_power_spectral_density(df):
    df_psd = np.abs(df)**2
    return df_psd.sum()

#generate windows with 50% overlap
def windows(df, time, overlap):
    start = df.iloc[0]
    while  (start + pd.to_timedelta(time, unit='s')) < df.iloc[-1]:
        yield start, (start + pd.to_timedelta(time, unit='s'))
        if overlap:
            start += pd.to_timedelta(time/2, unit='s')
        else:
            start += pd.to_timedelta(time, unit='s')
    #last samples 
    yield (df.iloc[-1] - pd.to_timedelta(time, unit='s')), df.iloc[-1]
        
def feature_extraction_segmentation(data, window, overlap):
    column_names = ["x_mean", "y_mean", "z_mean", "x_min", "y_min", "z_min", "x_max", "y_max", "z_max",
                "x_std", "y_std", "z_std", "x_med", "y_med", "z_med", "activity"]
    df = pd.DataFrame(columns = column_names)

    for (start, end) in windows(data['time'], window, overlap):
        vw1 = data['time'] >= start
        vw2 = data['time'] < end
        mean = get_mean_window(data[vw1 & vw2])
        min = get_min_window(data[vw1 & vw2])
        max = get_max_window(data[vw1 & vw2])
        std = get_std_window(data[vw1 & vw2])
        med = get_med_window(data[vw1 & vw2])
        sma = get_signal_magnitude_area(data[vw1 & vw2])
        smv = get_signal_magnitude_vector(data[vw1 & vw2])
        tilt = get_tilt_angle(data[vw1 & vw2])
        #fourrier transform
        t_x = data[vw1 & vw2][['time','x']].set_index('time')
        t_y = data[vw1 & vw2][['time','y']].set_index('time')
        t_z = data[vw1 & vw2][['time', 'z']].set_index('time')

        df_f = pd.DataFrame(columns=['f', 'x_f', 'y_f', 'z_f'])

        sampling_rate = 52

        df_f['x_f'] = FFT.fft(t_x).ravel()
        df_f['y_f'] = FFT.fft(t_y).ravel()
        df_f['z_f'] = FFT.fft(t_z).ravel()
        df_f['f'] = FFT.fftfreq(len(df_f['x_f'])) * sampling_rate

        psd = get_power_spectral_density(df_f)

        df = df.append(pd.Series({'x_mean': mean['x'], 'y_mean': mean['y'], 'z_mean': mean['z'], "x_min" : min['x'],
                              "y_min" : min['y'], "z_min" : min['z'], "x_max" : max['x'], "y_max" : max['y'], "z_max" : max['z'],
                              "x_std" : std['x'], "y_std" : std['y'], "z_std" : std['z'], "x_med" : med['x'], "y_med" : med['y'], "z_med" : med['z'],
                              "sma" : sma, "smv" : smv, "tilt" : tilt, "x_psd" : psd['x_f'], "y_psd" : psd['y_f'], "z_psd" : psd['z_f']
                              , "activity" : data['activity'].iloc[0]}), ignore_index=True) # "x_entropy" : entropy[0], "y_entropy" : entropy[1], "z_entropy" : entropy[2],
    return df


column_names_org = ['time', 'x', 'y', 'z']

# %%
raw = True
freq = 0

# %% [markdown]
# # <font color='green' >PROEFPERSOON 1

# %% [markdown]
# ## side swing

# %%
side_swing_left_forward_1 = []
side_swing_right_forward_1 = []
side_swing_left_backwards_1 = []
side_swing_right_backwards_1 = []

# %% [markdown]
# #### side_swing_left_forward

# %%
side_swing4 = pd.read_csv(r"..\data\side_swing\proefpersoon1\side_swing_left_forward-tim.csv", sep=';', header=0, skipinitialspace=True)
side_swing5 = pd.read_csv(r"..\data\side_swing\proefpersoon1\side_swing_left_forward_tim.csv", sep=';', header=0, skipinitialspace=True)

side_swing4 = preprocess(side_swing4, "side_swing", "left_forward", 1, 3, 4)
side_swing5 = preprocess(side_swing5, "side_swing", "left_forward", 1)

side_swing_left_forward_1 = [ side_swing4,side_swing5]

# %%
side_swing4.drop("proefpersoon", axis=1).plot(x='time', subplots=True)
# Out:
# <img src="data:image/png;base64,..." width="1200">
# array([<matplotlib.axes._subplots.AxesSubplot object at 0x0000025C02EE6788>,
# ...
#       dtype=object)

# %%
for df in side_swing_left_forward_1:
    f = sampling_freq(df)
    freq += f

# %% [markdown]
# #### side_swing_right_forward

# %%
side_swing_rigth = pd.read_csv(r"..\data\side_swing\proefpersoon1\side_swing_tim.csv", sep=';', header=0, skipinitialspace=True)
side_swing_rigth1 = pd.read_csv(r"..\data\side_swing\proefpersoon1\side_swing_right_forward_tim.csv", sep=';', header=0, skipinitialspace=True)

side_swing_rigth = preprocess(side_swing_rigth, "side_swing", "right_forward", 1)
side_swing_rigth1 = preprocess(side_swing_rigth1, "side_swing", "right_forward", 1)

side_swing_right_forward_1 = [side_swing_rigth, side_swing_rigth1]

# %%
for df in side_swing_right_forward_1:
    f = sampling_freq(df)
    freq += f

# %% [markdown]
# #### side_swing_left_backwards

# %%
side_swing_left_backwards1 = pd.read_csv(r"..\data\side_swing\proefpersoon1\side_swing_left_backwards_tim1.csv", sep=';', header=0, skipinitialspace=True)
side_swing_left_backwards2 = pd.read_csv(r"..\data\side_swing\proefpersoon1\side_swing_left_backwards_tim2.csv", sep=';', header=0, skipinitialspace=True)
side_swing_left_backwards3 = pd.read_csv(r"..\data\side_swing\proefpersoon1\side_swing_left_backwards_tim3.csv", sep=';', header=0, skipinitialspace=True)
side_swing_left_backwards4 = pd.read_csv(r"..\data\side_swing\proefpersoon1\side_swing_left_backwards_tim4.csv", sep=';', header=0, skipinitialspace=True)
side_swing_left_backwards5 = pd.read_csv(r"..\data\side_swing\proefpersoon1\side_swing_left_backwards_tim5.csv", sep=';', header=0, skipinitialspace=True)
side_swing_left_backwards6 = pd.read_csv(r"..\data\side_swing\proefpersoon1\side_swing_left_backwards_tim6.csv", sep=';', header=0, skipinitialspace=True)
side_swing_left_backwards7 = pd.read_csv(r"..\data\side_swing\proefpersoon1\side_swing_left_backwards_tim8.csv", sep=';', header=0, skipinitialspace=True)
side_swing_left_backwards8 = pd.read_csv(r"..\data\side_swing\proefpersoon1\side_swing_left_backwards_tim9.csv", sep=';', header=0, skipinitialspace=True)
side_swing_left_backwards9 = pd.read_csv(r"..\data\side_swing\proefpersoon1\side_swing_left_backwards_tim.csv", sep=';', header=0, skipinitialspace=True)

side_swing_left_backwards1 = preprocess(side_swing_left_backwards1, "side_swing", "left_backwards", 1)
side_swing_left_backwards2 = preprocess(side_swing_left_backwards2, "side_swing", "left_backwards", 1,1,0)
side_swing_left_backwards3 = preprocess(side_swing_left_backwards3, "side_swing", "left_backwards", 1,0,0)
side_swing_left_backwards4 = preprocess(side_swing_left_backwards4, "side_swing", "left_backwards", 1,0,0)
side_swing_left_backwards5 = preprocess(side_swing_left_backwards5, "side_swing", "left_backwards", 1,0,0)
side_swing_left_backwards6 = preprocess(side_swing_left_backwards6, "side_swing", "left_backwards", 1,0,0)
side_swing_left_backwards7 = preprocess(side_swing_left_backwards7, "side_swing", "left_backwards", 1,0,0)
side_swing_left_backwards8 = preprocess(side_swing_left_backwards8, "side_swing", "left_backwards", 1,0,3)
side_swing_left_backwards9 = preprocess(side_swing_left_backwards9, "side_swing", "left_backwards", 1)

side_swing_left_backwards_1 = [side_swing_left_backwards2, side_swing_left_backwards3, 
                               side_swing_left_backwards4, side_swing_left_backwards5, side_swing_left_backwards6, side_swing_left_backwards7, side_swing_left_backwards8, side_swing_left_backwards9]

# %%
for df in side_swing_left_backwards_1:
    f = sampling_freq(df)
    freq += f

# %% [markdown]
# #### side_swing_right_backwards

# %%
side_swing_right_backwards1 = pd.read_csv(r"..\data\side_swing\proefpersoon1\side_swing_right_backwards_tim1.csv", sep=';', header=0, skipinitialspace=True)
side_swing_right_backwards2 = pd.read_csv(r"..\data\side_swing\proefpersoon1\side_swing_right_backwards_tim2.csv", sep=';', header=0, skipinitialspace=True)
side_swing_right_backwards3 = pd.read_csv(r"..\data\side_swing\proefpersoon1\side_swing_right_backwards_tim3.csv", sep=';', header=0, skipinitialspace=True)
side_swing_right_backwards4 = pd.read_csv(r"..\data\side_swing\proefpersoon1\side_swing_right_backwards_tim4.csv", sep=';', header=0, skipinitialspace=True)
side_swing_right_backwards5 = pd.read_csv(r"..\data\side_swing\proefpersoon1\side_swing_right_backwards_tim5.csv", sep=';', header=0, skipinitialspace=True)
side_swing_right_backwards6 = pd.read_csv(r"..\data\side_swing\proefpersoon1\side_swing_right_backwards_tim7.csv", sep=';', header=0, skipinitialspace=True)
side_swing_right_backwards7 = pd.read_csv(r"..\data\side_swing\proefpersoon1\side_swing_right_backwards_tim8.csv", sep=';', header=0, skipinitialspace=True)
side_swing_right_backwards8 = pd.read_csv(r"..\data\side_swing\proefpersoon1\side_swing_right_backwards_tim.csv", sep=';', header=0, skipinitialspace=True)

side_swing_right_backwards1 = preprocess(side_swing_right_backwards1, "side_swing", "right_backwards", 1)
side_swing_right_backwards2 = preprocess(side_swing_right_backwards2, "side_swing", "right_backwards", 1,1,0)
side_swing_right_backwards3 = preprocess(side_swing_right_backwards3, "side_swing", "right_backwards", 1,0,0)
side_swing_right_backwards4 = preprocess(side_swing_right_backwards4, "side_swing", "right_backwards", 1,0,0)
side_swing_right_backwards5 = preprocess(side_swing_right_backwards5, "side_swing", "right_backwards", 1,0,0)
side_swing_right_backwards6 = preprocess(side_swing_right_backwards6, "side_swing", "right_backwards", 1,0,0)
side_swing_right_backwards7 = preprocess(side_swing_right_backwards7, "side_swing", "right_backwards", 1,0,3)
side_swing_right_backwards8 = preprocess(side_swing_right_backwards8, "side_swing", "right_backwards", 1)

side_swing_right_backwards_1 = [ side_swing_right_backwards2, side_swing_right_backwards3, 
                               side_swing_right_backwards4, side_swing_right_backwards5, side_swing_right_backwards6, side_swing_right_backwards7, side_swing_right_backwards8]

# %%
for df in side_swing_right_backwards_1:
    f = sampling_freq(df)
    freq += f

# %% [markdown]
# ## SEGMENTATION

# %%
if(not raw):
    #segmentation + feature extraction
    print(side_swing_right_forward_1[0].columns)
    for i in range(0, len(side_swing_left_forward_1)):
        side_swing_left_forward_1[i] =  feature_extraction_segmentation(side_swing_left_forward_1[i],1, True)

    for i in range(0, len(side_swing_right_forward_1)):
        side_swing_right_forward_1[i] =  feature_extraction_segmentation(side_swing_right_forward_1[i],1, True)

    for i in range(0, len(side_swing_left_backwards_1)):
        side_swing_left_backwards_1[i] =  feature_extraction_segmentation(side_swing_left_backwards_1[i],1, True)

    for i in range(0, len(side_swing_right_backwards_1)):
        side_swing_right_backwards_1[i] =  feature_extraction_segmentation(side_swing_right_backwards_1[i],1, True)

# %%
side_swing_right_backwards_1  = pd.concat(side_swing_right_backwards_1, ignore_index=True)
side_swing_right_backwards_1.shape
# Out:
# (6333, 7)

# %%
side_swing_left_forward_1  = pd.concat(side_swing_left_forward_1, ignore_index=True)
side_swing_left_forward_1.shape
# Out:
# (5141, 7)

# %%
side_swing_right_forward_1  = pd.concat(side_swing_right_forward_1, ignore_index=True)
side_swing_right_forward_1.shape
# Out:
# (5495, 7)

# %%
side_swing_left_backwards_1  = pd.concat(side_swing_left_backwards_1, ignore_index=True)
side_swing_left_backwards_1.shape
# Out:
# (9013, 7)

# %% [markdown]
# ### SHUFFLE - BALANCING

# %%
shape = np.min([
    side_swing_right_backwards_1.shape[0], 
    side_swing_left_forward_1.shape[0], 
    side_swing_right_forward_1.shape[0], 
    side_swing_left_backwards_1.shape[0]])

# %% [markdown]
# #### shuffle

# %%
''' 
side_swing_right_backwards_1 = shuffle(side_swing_right_backwards_1).head(shape).copy()
side_swing_left_forward_1 = shuffle(side_swing_left_forward_1).head(shape).copy()
side_swing_right_forward_1 = shuffle(side_swing_right_forward_1).head(shape).copy()
side_swing_left_backwards_1 = shuffle(side_swing_left_backwards_1).head(shape).copy()'''
# Out:
# ' \nside_swing_right_backwards_1 = shuffle(side_swing_right_backwards_1).head(shape).copy()\nside_swing_left_forward_1 = shuffle(side_swing_left_forward_1).head(shape).copy()\nside_swing_right_forward_1 = shuffle(side_swing_right_forward_1).head(shape).copy()\nside_swing_left_backwards_1 = shuffle(side_swing_left_backwards_1).head(shape).copy()'

# %% [markdown]
# #### no shuffle

# %%
'''
side_swing_right_backwards_1 = side_swing_right_backwards_1.head(shape).copy()
side_swing_left_forward_1 = side_swing_left_forward_1.head(shape).copy()
side_swing_right_forward_1 = side_swing_right_forward_1.head(shape).copy()
side_swing_left_backwards_1 = side_swing_left_backwards_1.head(shape).copy() '''
# Out:
# '\nside_swing_right_backwards_1 = side_swing_right_backwards_1.head(shape).copy()\nside_swing_left_forward_1 = side_swing_left_forward_1.head(shape).copy()\nside_swing_right_forward_1 = side_swing_right_forward_1.head(shape).copy()\nside_swing_left_backwards_1 = side_swing_left_backwards_1.head(shape).copy() '

# %% [markdown]
# # <font color='green' >PROEFPERSOON 2

# %% [markdown]
# ## side swing

# %%
side_swing_left_forward_2 = []
side_swing_right_forward_2 = []
side_swing_left_backwards_2 = []
side_swing_right_backwards_2 = []

# %% [markdown]
# #### side_swing_left_forward

# %%
side_swing = pd.read_csv(r"..\data\side_swing\proefpersoon2\side_swing.csv", sep=';', header=0, skipinitialspace=True)
side_swing2 = pd.read_csv(r"..\data\side_swing\proefpersoon2\side_swing2 (meting2).csv", sep=';', header=0, skipinitialspace=True)
side_swing3 = pd.read_csv(r"..\data\side_swing\proefpersoon2\side_swing3 (meting2).csv", sep=';', header=0, skipinitialspace=True)
side_swing4 = pd.read_csv(r"..\data\side_swing\proefpersoon2\side_swing_left_forward.csv", sep=';', header=0, skipinitialspace=True)

side_swing = preprocess(side_swing, "side_swing", "left_forward",2)
side_swing2 = preprocess(side_swing2, "side_swing", "left_forward",2)
side_swing3 = preprocess(side_swing3, "side_swing", "left_forward",2)
side_swing4 = preprocess(side_swing4, "side_swing", "left_forward",2)

side_swing_left_forward_2 = [side_swing, side_swing2, side_swing3, side_swing4]

# %%
for df in side_swing_left_forward_2:
    f = sampling_freq(df)
    freq += f

# %% [markdown]
# #### side_swing_right_forward

# %%
side_swing_right_forward1 = pd.read_csv(r"..\data\side_swing\proefpersoon2\side_swing_right_forward.csv", sep=';', header=0, skipinitialspace=True)
side_swing_right_forward2 = pd.read_csv(r"..\data\side_swing\proefpersoon2\side_swing_right_forward(2).csv", sep=';', header=0, skipinitialspace=True)

side_swing_right_forward1 = preprocess(side_swing_right_forward1, "side_swing", "right_forward",2)
side_swing_right_forward2 = preprocess(side_swing_right_forward2, "side_swing", "right_forward",2)

side_swing_right_forward_2 = [side_swing_right_forward1, side_swing_right_forward2]

# %%
for df in side_swing_right_forward_2:
    f = sampling_freq(df)
    freq += f

# %% [markdown]
# #### side_swing_left_backwards

# %%
side_swing_left_backwards1 = pd.read_csv(r"..\data\side_swing\proefpersoon2\side_swing_backwards.csv", sep=';', header=0, skipinitialspace=True)
side_swing_left_backwards2 = pd.read_csv(r"..\data\side_swing\proefpersoon2\side_swing_left_backwards.csv", sep=';', header=0, skipinitialspace=True)

side_swing_left_backwards1 = preprocess(side_swing_left_backwards1, "side_swing", "left_backwards",2)
side_swing_left_backwards2 = preprocess(side_swing_left_backwards2, "side_swing", "left_backwards",2,3,4)

side_swing_left_backwards_2 = [side_swing_left_backwards1, side_swing_left_backwards2]

# %%
for df in side_swing_left_backwards_2:
    f = sampling_freq(df)
    freq += f

# %% [markdown]
# #### side_swing_right_backwards

# %%
side_swing_right_backwards1 = pd.read_csv(r"..\data\side_swing\proefpersoon2\side_swing_right_backwards1.csv", sep=';', header=0, skipinitialspace=True)
side_swing_right_backwards2 = pd.read_csv(r"..\data\side_swing\proefpersoon2\side_swing_right_backwards2.csv", sep=';', header=0, skipinitialspace=True)
side_swing_right_backwards3 = pd.read_csv(r"..\data\side_swing\proefpersoon2\side_swing_right_backwards3.csv", sep=';', header=0, skipinitialspace=True)
side_swing_right_backwards4 = pd.read_csv(r"..\data\side_swing\proefpersoon2\side_swing_right_backwards.csv", sep=';', header=0, skipinitialspace=True)

side_swing_right_backwards1 = preprocess(side_swing_right_backwards1, "side_swing", "right_backwards",2,3,0)
side_swing_right_backwards2 = preprocess(side_swing_right_backwards2, "side_swing", "right_backwards",2,0,0)
side_swing_right_backwards3 = preprocess(side_swing_right_backwards3, "side_swing", "right_backwards",2,0,3)
side_swing_right_backwards4 = preprocess(side_swing_right_backwards4, "side_swing", "right_backwards",2)

side_swing_right_backwards_2 = [side_swing_right_backwards1, side_swing_right_backwards2, side_swing_right_backwards3,side_swing_right_backwards4]

# %%
for df in side_swing_right_backwards_2:
    f = sampling_freq(df)
    freq += f

# %% [markdown]
# ### SEGMENTATION

# %%
if(not raw):
    #segmentation + feature extraction
    for i in range(0, len(side_swing_left_forward_2)):
        side_swing_left_forward_2[i] =  feature_extraction_segmentation(side_swing_left_forward_2[i],1, True)

    for i in range(0, len(side_swing_right_forward_2)):
        side_swing_right_forward_2[i] =  feature_extraction_segmentation(side_swing_right_forward_2[i],1, True)

    for i in range(0, len(side_swing_left_backwards_2)):
        side_swing_left_backwards_2[i] =  feature_extraction_segmentation(side_swing_left_backwards_2[i],1, True)

    for i in range(0, len(side_swing_right_backwards_2)):
        side_swing_right_backwards_2[i] =  feature_extraction_segmentation(side_swing_right_backwards_2[i],1, True)

# %%
side_swing_right_backwards_2  = pd.concat(side_swing_right_backwards_2, ignore_index=True)
side_swing_right_backwards_2.shape
# Out:
# (9481, 7)

# %%
side_swing_left_forward_2  = pd.concat(side_swing_left_forward_2, ignore_index=True)
side_swing_left_forward_2.shape
# Out:
# (8824, 7)

# %%
side_swing_right_forward_2  = pd.concat(side_swing_right_forward_2, ignore_index=True)
side_swing_right_forward_2.shape
# Out:
# (9244, 7)

# %%
side_swing_left_backwards_2  = pd.concat(side_swing_left_backwards_2, ignore_index=True)
side_swing_left_backwards_2.shape
# Out:
# (11682, 7)

# %% [markdown]
# ### SHUFFLE - BALANCING

# %%
shape = np.min([
    side_swing_right_backwards_2.shape[0], 
    side_swing_left_forward_2.shape[0], 
    side_swing_right_forward_2.shape[0], 
    side_swing_left_backwards_2.shape[0]])

# %% [markdown]
# #### shuffle

# %%
''' 
side_swing_right_backwards_2 = shuffle(side_swing_right_backwards_2).head(shape).copy()
side_swing_left_forward_2 = shuffle(side_swing_left_forward_2).head(shape).copy()
side_swing_right_forward_2 = shuffle(side_swing_right_forward_2).head(shape).copy()
side_swing_left_backwards_2 = shuffle(side_swing_left_backwards_2).head(shape).copy()'''
# Out:
# ' \nside_swing_right_backwards_2 = shuffle(side_swing_right_backwards_2).head(shape).copy()\nside_swing_left_forward_2 = shuffle(side_swing_left_forward_2).head(shape).copy()\nside_swing_right_forward_2 = shuffle(side_swing_right_forward_2).head(shape).copy()\nside_swing_left_backwards_2 = shuffle(side_swing_left_backwards_2).head(shape).copy()'

# %% [markdown]
# #### no shuffle

# %%
''' 
side_swing_right_backwards_2 = side_swing_right_backwards_2.head(shape).copy()
side_swing_left_forward_2 = side_swing_left_forward_2.head(shape).copy()
side_swing_right_forward_2 = side_swing_right_forward_2.head(shape).copy()
side_swing_left_backwards_2 = side_swing_left_backwards_2.head(shape).copy()'''
# Out:
# ' \nside_swing_right_backwards_2 = side_swing_right_backwards_2.head(shape).copy()\nside_swing_left_forward_2 = side_swing_left_forward_2.head(shape).copy()\nside_swing_right_forward_2 = side_swing_right_forward_2.head(shape).copy()\nside_swing_left_backwards_2 = side_swing_left_backwards_2.head(shape).copy()'

# %% [markdown]
# # <font color='green' >PROEFPERSOON 3

# %% [markdown]
# ## side swing

# %%
side_swing_left_forward_3 = []
side_swing_right_forward_3 = []
side_swing_left_backwards_3 = []
side_swing_right_backwards_3 = []

# %% [markdown]
# #### side_swing_left_forward

# %%
side_swing = pd.read_csv(r"..\data_3\side_swing\proefpersoon3\acceleroData_left_forward_sideswing_mama.csv", sep=';', header=0, skipinitialspace=True)

side_swing = preprocess(side_swing, "side_swing", "left_forward",3,3,5)

side_swing_left_forward_3 = [side_swing]

# %% [markdown]
# #### side_swing_right_forward

# %%
side_swing_right_forward1 = pd.read_csv(r"..\data_3\side_swing\proefpersoon3\acceleroData_right_forward_sideswing_mama.csv", sep=';', header=0, skipinitialspace=True)

side_swing_right_forward1 = preprocess(side_swing_right_forward1, "side_swing", "right_forward",3,3,5)

side_swing_right_forward_3 = [side_swing_right_forward1]

# %% [markdown]
# #### side_swing_left_backwards

# %% [markdown]
# #### side_swing_right_backwards

# %% [markdown]
# ### SEGMENTATION

# %%
if(not raw):
    #segmentation + feature extraction
    for i in range(0, len(side_swing_left_forward_2)):
        side_swing_left_forward_2[i] =  feature_extraction_segmentation(side_swing_left_forward_2[i],1, True)

    for i in range(0, len(side_swing_right_forward_2)):
        side_swing_right_forward_2[i] =  feature_extraction_segmentation(side_swing_right_forward_2[i],1, True)

    for i in range(0, len(side_swing_left_backwards_2)):
        side_swing_left_backwards_2[i] =  feature_extraction_segmentation(side_swing_left_backwards_2[i],1, True)

    for i in range(0, len(side_swing_right_backwards_2)):
        side_swing_right_backwards_2[i] =  feature_extraction_segmentation(side_swing_right_backwards_2[i],1, True)

# %%
side_swing_left_forward_3  = pd.concat(side_swing_left_forward_3, ignore_index=True)
side_swing_left_forward_3.shape
# Out:
# (2499, 7)

# %%
side_swing_right_forward_3  = pd.concat(side_swing_right_forward_3, ignore_index=True)
side_swing_right_forward_3.shape
# Out:
# (2292, 7)

# %% [markdown]
# # <font color='green' >PROEFPERSOON 4

# %% [markdown]
# ## side swing

# %%
side_swing_left_forward_4 = []
side_swing_right_forward_4 = []
side_swing_left_backwards_4 = []
side_swing_right_backwards_4 = []

# %% [markdown]
# #### side_swing_left_forward

# %%
side_swing = pd.read_csv(r"..\data_3\side_swing\proefpersoon4\acceleroData_side_left_forward_boni.csv", sep=';', header=0, skipinitialspace=True)

side_swing = preprocess(side_swing, "side_swing", "left_forward",4,3,5)

side_swing_left_forward_4 = [side_swing]

# %% [markdown]
# #### side_swing_right_forward

# %%
side_swing_right_forward1 = pd.read_csv(r"..\data_3\side_swing\proefpersoon4\acceleroData_side_right_forward_boni.csv", sep=';', header=0, skipinitialspace=True)
side_swing_right_forward2 = pd.read_csv(r"..\data_3\side_swing\proefpersoon4\acceleroData_side_right_forward_boni2.csv", sep=';', header=0, skipinitialspace=True)

side_swing_right_forward1 = preprocess(side_swing_right_forward1, "side_swing", "right_forward",4,3,15)
side_swing_right_forward2 = preprocess(side_swing_right_forward2, "side_swing", "right_forward",4,3,10)

side_swing_right_forward_4 = [side_swing_right_forward1, side_swing_right_forward2]

# %%
side_swing_right_forward2.plot(x='time', subplots=True)
# Out:
# <img src="data:image/png;base64,..." width="1200">
# array([<matplotlib.axes._subplots.AxesSubplot object at 0x000001C844B3AD08>,
# ...
#       dtype=object)

# %% [markdown]
# #### side_swing_left_backwards

# %% [markdown]
# #### side_swing_right_backwards

# %% [markdown]
# ### SEGMENTATION

# %%
if(not raw):
    #segmentation + feature extraction
    for i in range(0, len(side_swing_left_forward_2)):
        side_swing_left_forward_2[i] =  feature_extraction_segmentation(side_swing_left_forward_2[i],1, True)

    for i in range(0, len(side_swing_right_forward_2)):
        side_swing_right_forward_2[i] =  feature_extraction_segmentation(side_swing_right_forward_2[i],1, True)

    for i in range(0, len(side_swing_left_backwards_2)):
        side_swing_left_backwards_2[i] =  feature_extraction_segmentation(side_swing_left_backwards_2[i],1, True)

    for i in range(0, len(side_swing_right_backwards_2)):
        side_swing_right_backwards_2[i] =  feature_extraction_segmentation(side_swing_right_backwards_2[i],1, True)

# %%
side_swing_left_forward_4  = pd.concat(side_swing_left_forward_4, ignore_index=True)
side_swing_left_forward_4.shape
# Out:
# (2798, 7)

# %%
side_swing_right_forward_4  = pd.concat(side_swing_right_forward_4, ignore_index=True)
side_swing_right_forward_4.shape
# Out:
# (2413, 7)

# %% [markdown]
# # <font color='green'> Frequency

# %%
#mean
freq = freq/23
freq

# %% [markdown]
# # <font color='green'> Merging datasets

# %%
shape = np.min([
    side_swing_1.shape[0],
    side_swing_2.shape[0]
])

# %% [markdown]
# #### shuffle

# %%
''' 
dataset = pd.concat([
    shuffle(side_swing_1).head(shape),
    shuffle(side_swing_2).head(shape)
])
dataset.shape'''

# %% [markdown]
# #### no shuffle

# %%
''' 
dataset = pd.concat([
    side_swing_1.head(shape),
    side_swing_2.head(shape)
])
dataset.shape'''

# %%
side_swing_right_backwards = pd.concat([
    side_swing_right_backwards_2,
    side_swing_right_backwards_1
])
side_swing_left_backwards = pd.concat([
    side_swing_left_backwards_2,
    side_swing_left_backwards_1
])
side_swing_right_forward = pd.concat([
    side_swing_right_forward_4,
    side_swing_right_forward_3,
    side_swing_right_forward_2,
    side_swing_right_forward_1
])
side_swing_left_forward = pd.concat([
    side_swing_left_forward_4,
    side_swing_left_forward_3,
    side_swing_left_forward_2,
    side_swing_left_forward_1
])

# %%
side_swing_right_backwards.to_csv("side_swing_right_backwards.csv", sep=';')
side_swing_left_backwards.to_csv("side_swing_left_backwards.csv", sep=';')
side_swing_right_forward.to_csv("side_swing_right_forward.csv", sep=';')
side_swing_left_forward.to_csv("side_swing_left_forward.csv", sep=';')

# %%
side_swing_right_backwards_1.to_csv("side_swing_right_backwards_1.csv", sep=';')
side_swing_left_backwards_1.to_csv("side_swing_left_backwards_1.csv", sep=';')
side_swing_right_forward_1.to_csv("side_swing_right_forward_1.csv", sep=';')
side_swing_left_forward_1.to_csv("side_swing_left_forward_1.csv", sep=';')

# %%
side_swing_right_backwards_2.to_csv("side_swing_right_backwards_2.csv", sep=';')
side_swing_left_backwards_2.to_csv("side_swing_left_backwards_2.csv", sep=';')
side_swing_right_forward_2.to_csv("side_swing_right_forward_2.csv", sep=';')
side_swing_left_forward_2.to_csv("side_swing_left_forward_2.csv", sep=';')

# %%
#dataset.to_csv("side_swing_raw.csv", sep=';')
